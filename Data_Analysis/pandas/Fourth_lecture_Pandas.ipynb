# %% [markdown]
# #CSV

# %%
import pandas as pd

# %%
fil1 = pd.read_csv("/content/testdata.csv")
# if you have tcs file you can using this functiona
# and setup the sep argument="\t"

# %%
fil2 = pd.read_csv("/content/testdata.csv", usecols=[" Name"])
# usecols ... for select the columns

# %%
fil2
# Out:
#       Name
# 0   Eshraq
# 1    Ahmad
# 2    esraa

# %%
fil2.columns
# Out:
# Index(['Id', ' Name', ' age'], dtype='object')

# %%
fil2 = pd.read_csv("/content/testdata.csv", usecols=["Id"])

# %%
type(fil2.loc[0, "Id"])
# Series as a numpy
# Out:
# numpy.int64

# %%
type(fil2["Id"])
# Out:
# pandas.core.series.Series

# %%
# converters processing in the one column when reading it
fil2 = pd.read_csv("/content/testdata.csv", usecols=["Id"], converters={"Id":lambda age: age*2} )

# %%
fil2
# Out:
#    Id
# 0  11
# 1  22
# 2  33

# %%
fil2.to_csv("new.csv", index=False)

# %%
fil4= pd.read_csv("/content/new.csv")

# %%
fil4
# Out:
#    Id
# 0  11
# 1  22
# 2  33

# %% [markdown]
# #Excel

# %%
# Pandas can read and write excel files, keep in mind, this only imports data.
# Not formulas or images,
# having images or macros may cause this read_excel method to crash.

# %%
# Excel file have alot of the Sheet, select one using sheet_name argument

# %%
fil1 = pd.read_excel("/content/newtest.xlsx", sheet_name="Sheet1")

# %%
fil1
# Out:
# Empty DataFrame
# Columns: [ert, ert.1]
# Index: []

# %%
fil1.to_excel("oldtest.xlsx", sheet_name="eshraq")

# %% [markdown]
# #Html

# %%
! pip install BeautifulSoup4

# %%
# web scraping
import lxml
import html5lib
from bs4 import BeautifulSoup

# %%
df = pd.read_html("http://www.fdic.gov/bank/individual/failed/banklist.html")

# %%
df
# Out:
# [                               Bank Name               City          State  \
#  0  Republic First Bank dba Republic Bank       Philadelphia   Pennsylvania
#  1                          Citizens Bank           Sac City           Iowa
#  2               Heartland Tri-State Bank            Elkhart         Kansas
#  3                    First Republic Bank      San Francisco     California
#  4                         Signature Bank           New York       New York
#  5                    Silicon Valley Bank        Santa Clara     California
#  6                      Almena State Bank             Almena         Kansas
#  7             First City Bank of Florida  Fort Walton Beach        Florida
#  8                   The First State Bank      Barboursville  West Virginia
#  9                     Ericson State Bank            Ericson       Nebraska
#
#      Cert                 Aquiring Institution       Closing Date   Fund
# ...

# %%
#SQL

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:') # temprory sqlite DB in M.M

# %%
with open("/content/test.sql","r") as d:
  test = d.read()

# %%
test
# Out:
# ''

# %%
# sql_df = pd.read_sql(name of table, con=engine)

# %%
# after processing
df.to_sql('data', engine)

# %%
# if_exists='fail' لما ارفع ال table وكان بالاصل موجود
# يلغي الرفع / يضيف الداتا اللي بالجدول الجديد ع الموجود اصلا
# او يبدل الجدول الجديد بالموجود اصلا
# index=True, اذا درفع ال index  as column اللي بالجدول
