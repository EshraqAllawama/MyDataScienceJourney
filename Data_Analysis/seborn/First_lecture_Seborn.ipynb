# %%
# ststaical_visualization_data
# seborn built over in matplotlib
# legened exist by defult not as a matplotlib
# numrical var
# الافريج بتاثر بالاكستريم فاليوم,

# %% [markdown]
# #the distribution plots
# بوضحلي توزيع الداتا
# **bold text**

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Seaborn comes with built-in data sets!

# %%
data_1 = sns.load_dataset("tips")
# data of بقشيش

# %%
data_1.head()
# columns -> 1 and 2 and 7 is numerical
# else than is catorigal, and sex is binary catorigal
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# requarments -> lib and version
#sns.distplot -> histplot, displot in new version

# %%
len(data_1)
# Out:
# 244

# %%
# hist for uni
# univarite plot -> info for one variable ->  hist, and pdf
# bi else that
# using continue vlue not discrate as day
# ممكن نحكي الدسكريت فاليو بتشبه الكاتوغريال, مش تماما, والكونيتينو بتشبه النرميكل
# cat -> static of number
# for univarite plot
sns.distplot(data_1['total_bill'])
# below
# 1 -> sortin of data
# 2 -> density -> نسبة بين معين بالنسبة لداتا سسيت كاملة
# Out:
# <ipython-input-19-211c68f87213>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# pdf (Probability Density Function)  يؤدي الى رسم
# اي رسمة بغض النظر بس بتكون غاوس, وبالنسبة لفكرة النواة هي بتجعل بشكل سموذي مش حاد عند النقاط, بتبين نواة حول كل نقطة وهيك
# , ومنها طلع ال
# kde (Kernel Density Estimation) deal with continues values , value by value ) لهيك طلع اسمه كيرنل لانه بعمل نواة حوالين كل value, وبعمل لكل data -> dist , بعدها بجمعهم وبطلع kde )  لحال
#
# Gaussian dist -> normal dist

# %%
#Probability Density -> بعطي توزيع الداتا ونورمال اولا, بتعامل مع كل بوينت لحالها
# max ->52, min -> 4 , a spesfic vlaues read by hist

# %%
sns.distplot(data_1['size'])
# Out:
# <ipython-input-18-3988f4c1bd25>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['size'])
# <Axes: xlabel='size', ylabel='Density'>

# %%
sns.histplot(data_1['size'])
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
sns.displot(data_1['size'])

# %%
# more bins, more resluation
sns.distplot(data_1['total_bill'], kde = False, bins = 50) # # of bin defult by lib as optimal value
# Out:
# <ipython-input-23-1ca69ff478e3>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['total_bill'], kde = False, bins = 50)
# <Axes: xlabel='total_bill'>

# %%
data_2 = np.random.exponential(1/lambda_rate, 1000)
sns.distplot(data_2)
# التوزيع الاسي نوع من انواع ارايت سكويد

# %% [markdown]
# #the joint plots

# %%
data_1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# for bi(two distplots for bivariate data) and uni
# to descaver realtion b et 2 var
# With your choice of what kind parameter to compare withو defult -> scatter
# scatter bet 2 num var
sns.jointplot(x='tip', y='total_bill', data=data_1, kind='scatter')

# %%
# dincity -> عدد النقاط
# pos corr
sns.distplot(data_1['tip'])
# Out:
# <ipython-input-29-1d92a92fd9cf>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %% [markdown]
# ![Screenshot 2025-03-07 152550.png](data:image/png;base64,...)

# %%
#outlire

# %%
sns.jointplot(x='tip', y='total_bill', data=data_1, kind='hex')
# dincity -> اغمق لون

# %%
# dincity -> بوضعح الكقافة وبغمل fit كعلاقة بين المتغيريين , علاقة خطية
sns.jointplot(x='tip', y='total_bill', data=data_1, kind='reg')
# المظلل -> Confidence Interval

# %% [markdown]
# #pairplot

# %%
# deal with numrical alawase aas basics
# uni -> hist
# bi -> scatter
sns.pairplot(data_1)
# bet the same var -> hist as uni
# else that scatter

# %%
sns.distplot(data_1['tip'])

# %%
# add a new var as ctgorial, as additinal info, hue -> dist3
sns.pairplot(data_1, hue='smoker') # bec add cat, aso diag_kind = kde

# %%
# Can do entire dataframe with orient='h'

sns.pairplot(data_1, hue='smoker', diag_kind='hist', kind='kde')

# %% [markdown]
# #rugplot

# %%
sns.rugplot(data_1['total_bill']) # as hist, but this spesfic not as groups for uni
# show each data as dash
# Out:
# <Axes: xlabel='total_bill'>

# %%
#sns.distplot(data_1['total_bill'])
sns.kdeplot(data_1['total_bill'])

sns.rugplot(data_1['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# #additinal

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:

    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)

    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
dataset # bet 0 and 1
# Out:
# array([-0.81163133,  0.17253574, -0.02825686,  1.19688846,  0.18886156,
#         0.19929714,  1.29958088, -1.48140807,  1.64358754,  0.16074589,
#        -1.01367583, -0.17516606, -1.87151357,  0.95652118,  0.62245428,
#         0.28912494,  0.38232651, -0.01575523,  1.56293594,  1.1559448 ,
#         1.19601096,  0.28692287,  0.20625008,  0.07576632,  1.10336651])

# %%
# To get the kde plot we can sum these basis functions.

# Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list,axis=0)

# Plot figure
fig = plt.plot(x_axis,sum_of_kde,color='indianred')

# Add the initial rugplot
sns.rugplot(dataset,c = 'indianred')

# Get rid of y-tick marks
plt.yticks([])

# Set title
plt.suptitle("Sum of the Basis Functions")
